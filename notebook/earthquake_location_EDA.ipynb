# %%
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('Dataset/Processed_data/Earthquake_data_processed.xlsx')
data.sample(2)
# Out:
#                    Unnamed: 0  Latitude(deg)  Longitude(deg)  Depth(km)  \
# 16294 2001-07-17 12:16:27.330        36.0298       -117.8698       7.80
# 824   1971-12-12 05:53:36.570        37.7582       -122.1357       6.46
#
#        Magnitude(ergs)  No_of_Stations  Gap  Close   RMS   SRC   EventID  \
# 16294             3.25              15  185     21  0.06  NCSN  30224626
# 824               3.10              42   34      4  0.08  NCSN  -1008415
#
#        MagType_ML  MagType_Md  MagType_Mw  MagType_Mx
# 16294           0           1           0           0
# 824             1           0           0           0

# %%
sns.kdeplot(data,x="Latitude(deg)", multiple="stack")
# Out:
# c:\Users\PARTHIV\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Latitude(deg)', ylabel='Density'>

# %%
sns.kdeplot(data,x="Longitude(deg)", multiple="stack")
# Out:
# c:\Users\PARTHIV\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Longitude(deg)', ylabel='Density'>

# %%
from sklearn.preprocessing import PowerTransformer
lat_transformer = PowerTransformer(method='yeo-johnson', standardize=True)
long_transformer = PowerTransformer(method='yeo-johnson', standardize=True)

# %%
new_lat = lat_transformer.fit_transform(np.array(data['Latitude(deg)']).reshape(-1,1))
sns.kdeplot(new_lat, multiple="stack")
# Out:
# c:\Users\PARTHIV\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
new_long = long_transformer.fit_transform(np.array(data['Longitude(deg)']).reshape(-1,1))
sns.kdeplot(new_long, multiple="stack")
# Out:
# c:\Users\PARTHIV\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>
